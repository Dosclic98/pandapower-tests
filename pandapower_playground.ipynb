# %%
import pandapower as pp
from pandapower.networks import create_cigre_network_mv
from pandapower.plotting.plotly import pf_res_plotly

net = create_cigre_network_mv(with_der="all")

# %% [markdown]
# Transforming the HV network in the CIGRE-MV model to 220kV

# %%
# Transforming bus[0] in a 220kV bus
net.bus.at[0, "vn_kv"] = 220.0
# Transforming trafo[0] and trafo[1] in 220 kv --> 20kV busses 
net.trafo.at[0, "vn_hv_kv"] = 220.0
net.trafo.at[1, "vn_hv_kv"] = 220.0
print(f"## Bus 0 specs: \n{net.bus.iloc[0]}")
print(f"## Trafo 0 specs: \n{net.trafo.iloc[0]}")
print(f"## Trafo 1 specs: \n{net.trafo.iloc[1]}")
# Out:
# ## Bus 0 specs:
# name                                               Bus 0
# vn_kv                                              220.0
# type                                                   b
# zone                                            CIGRE_MV
# in_service                                          True
# geo           {"coordinates":[7.0,16.0], "type":"Point"}
# Name: 0, dtype: object
# ## Trafo 0 specs:
# name                       Trafo 0-1
# std_type                        None
# hv_bus                             0
# lv_bus                             1
# sn_mva                          25.0
# vn_hv_kv                       220.0
# vn_lv_kv                        20.0
# vk_percent                  12.00107
# vkr_percent                     0.16
# pfe_kw                           0.0
# i0_percent                       0.0
# shift_degree                    30.0
# tap_side                        None
# tap_neutral                      NaN
# tap_min                          NaN
# tap_max                          NaN
# tap_step_percent                 NaN
# tap_step_degree                  NaN
# tap_pos                          NaN
# tap_changer_type                 NaN
# id_characteristic_table         <NA>
# tap_dependency_table           False
# parallel                           1
# df                               1.0
# in_service                      True
# oltc                           False
# Name: 0, dtype: object
# ## Trafo 1 specs:
# name                       Trafo 0-12
# std_type                         None
# hv_bus                              0
# lv_bus                             12
# sn_mva                           25.0
# vn_hv_kv                        220.0
# vn_lv_kv                         20.0
# vk_percent                   12.00107
# vkr_percent                      0.16
# pfe_kw                            0.0
# i0_percent                        0.0
# shift_degree                     30.0
# tap_side                         None
# tap_neutral                       NaN
# tap_min                           NaN
# tap_max                           NaN
# tap_step_percent                  NaN
# tap_step_degree                   NaN
# tap_pos                           NaN
# tap_changer_type                  NaN
# id_characteristic_table          <NA>
# tap_dependency_table            False
# parallel                            1
# df                                1.0
# in_service                       True
# oltc                            False
# Name: 1, dtype: object

# %%
net.sgen
# Out:
#                        name  bus   p_mw  q_mvar  min_q_mvar  max_q_mvar  \
# 0                      PV 3    3  0.020     0.0         NaN         NaN
# 1                      PV 4    4  0.020     0.0         NaN         NaN
# 2                      PV 5    5  0.030     0.0         NaN         NaN
# 3                      PV 6    6  0.030     0.0         NaN         NaN
# 4                      PV 8    8  0.030     0.0         NaN         NaN
# 5                      PV 9    9  0.030     0.0         NaN         NaN
# 6                     PV 10   10  0.040     0.0         NaN         NaN
# 7                     PV 11   11  0.010     0.0         NaN         NaN
# 8                     WKA 7    7  1.500     0.0         NaN         NaN
# 9   Residential fuel cell 1    5  0.033     0.0         NaN         NaN
# 10             CHP diesel 1    9  0.310     0.0         NaN         NaN
# 11              Fuel cell 1    9  0.212     0.0         NaN         NaN
# 12  Residential fuel cell 2   10  0.014     0.0         NaN         NaN
#
#     sn_mva  scaling  controllable  id_q_capability_characteristic  \
# 0    0.020      1.0         False                            <NA>
# 1    0.020      1.0         False                            <NA>
# 2    0.030      1.0         False                            <NA>
# 3    0.030      1.0         False                            <NA>
# 4    0.030      1.0         False                            <NA>
# 5    0.030      1.0         False                            <NA>
# 6    0.040      1.0         False                            <NA>
# 7    0.010      1.0         False                            <NA>
# 8    1.500      1.0         False                            <NA>
# 9    0.033      1.0         False                            <NA>
# 10   0.310      1.0         False                            <NA>
# 11   0.212      1.0         False                            <NA>
# 12   0.014      1.0         False                            <NA>
#
#     reactive_capability_curve curve_style  in_service                   type  \
# 0                       False         NaN        True                     PV
# 1                       False         NaN        True                     PV
# 2                       False         NaN        True                     PV
# 3                       False         NaN        True                     PV
# 4                       False         NaN        True                     PV
# 5                       False         NaN        True                     PV
# 6                       False         NaN        True                     PV
# 7                       False         NaN        True                     PV
# 8                       False         NaN        True                     WP
# 9                       False         NaN        True  Residential fuel cell
# 10                      False         NaN        True             CHP diesel
# 11                      False         NaN        True              Fuel cell
# 12                      False         NaN        True  Residential fuel cell
#
#     current_source
# 0             True
# 1             True
# 2             True
# 3             True
# 4             True
# 5             True
# 6             True
# 7             True
# 8             True
# 9             True
# 10            True
# 11            True
# 12            True

# %% [markdown]
# Adding 100kV to each PV generator to match the Italian use-case

# %%
for i in range(0, 8):
    if net.sgen.at[i, "p_mw"] < 0.1: 
        net.sgen.at[i, "p_mw"] = net.sgen.at[i, "p_mw"] + 0.1 # Adding 0.1 MW to each PV generator 
        net.sgen.at[i, "q_mvar"] = net.sgen.at[i, "p_mw"] * 0.1
# Setting maximum active powert l
# Setting minimum and maximum reactive power limits for all generators (needed for OPF)
# Make all generators controllable if above 0.1 MW
for i in range(0, 13):
    if net.sgen.at[1, "type"] == "PV":
        net.sgen.at[i, "min_p_mw"] = net.sgen.at[i, "p_mw"]
        net.sgen.at[i, "max_p_mw"] = net.sgen.at[i, "p_mw"]
    else:
        net.sgen.at[i, "min_p_mw"] = net.sgen.at[i, "p_mw"] * 0.75
        net.sgen.at[i, "max_p_mw"] = net.sgen.at[i, "p_mw"] * 1.25
    net.sgen.at[i, "min_q_mvar"] = net.sgen.at[i, "q_mvar"] * 0.75
    net.sgen.at[i, "max_q_mvar"] = net.sgen.at[i, "q_mvar"] * 1.25
    if net.sgen.at[i, "p_mw"] >= 0.1:
        net.sgen.at[i, "controllable"] = True
net.sgen
# Out:
#                        name  bus   p_mw  q_mvar  min_q_mvar  max_q_mvar  \
# 0                      PV 3    3  0.120   0.012     0.00900     0.01500
# 1                      PV 4    4  0.120   0.012     0.00900     0.01500
# 2                      PV 5    5  0.130   0.013     0.00975     0.01625
# 3                      PV 6    6  0.130   0.013     0.00975     0.01625
# 4                      PV 8    8  0.130   0.013     0.00975     0.01625
# 5                      PV 9    9  0.130   0.013     0.00975     0.01625
# 6                     PV 10   10  0.140   0.014     0.01050     0.01750
# 7                     PV 11   11  0.110   0.011     0.00825     0.01375
# 8                     WKA 7    7  1.500   0.000     0.00000     0.00000
# 9   Residential fuel cell 1    5  0.033   0.000     0.00000     0.00000
# 10             CHP diesel 1    9  0.310   0.000     0.00000     0.00000
# 11              Fuel cell 1    9  0.212   0.000     0.00000     0.00000
# 12  Residential fuel cell 2   10  0.014   0.000     0.00000     0.00000
#
#     sn_mva  scaling  controllable  id_q_capability_characteristic  \
# 0    0.020      1.0          True                            <NA>
# 1    0.020      1.0          True                            <NA>
# 2    0.030      1.0          True                            <NA>
# 3    0.030      1.0          True                            <NA>
# 4    0.030      1.0          True                            <NA>
# 5    0.030      1.0          True                            <NA>
# 6    0.040      1.0          True                            <NA>
# 7    0.010      1.0          True                            <NA>
# 8    1.500      1.0          True                            <NA>
# 9    0.033      1.0         False                            <NA>
# 10   0.310      1.0          True                            <NA>
# 11   0.212      1.0          True                            <NA>
# 12   0.014      1.0         False                            <NA>
#
#     reactive_capability_curve curve_style  in_service                   type  \
# 0                       False         NaN        True                     PV
# 1                       False         NaN        True                     PV
# 2                       False         NaN        True                     PV
# 3                       False         NaN        True                     PV
# 4                       False         NaN        True                     PV
# 5                       False         NaN        True                     PV
# 6                       False         NaN        True                     PV
# 7                       False         NaN        True                     PV
# 8                       False         NaN        True                     WP
# 9                       False         NaN        True  Residential fuel cell
# 10                      False         NaN        True             CHP diesel
# 11                      False         NaN        True              Fuel cell
# 12                      False         NaN        True  Residential fuel cell
#
#     current_source  min_p_mw  max_p_mw
# 0             True     0.120     0.120
# 1             True     0.120     0.120
# 2             True     0.130     0.130
# 3             True     0.130     0.130
# 4             True     0.130     0.130
# 5             True     0.130     0.130
# 6             True     0.140     0.140
# 7             True     0.110     0.110
# 8             True     1.500     1.500
# 9             True     0.033     0.033
# 10            True     0.310     0.310
# 11            True     0.212     0.212
# 12            True     0.014     0.014

# %%
# Add bus voltage constraints
for i in range(len(net.bus)):
    net.bus.at[i, "min_vm_pu"] = 0.95
    net.bus.at[i, "max_vm_pu"] = 1.05
net.bus
# Out:
#       name  vn_kv type      zone  in_service  \
# 0    Bus 0  220.0    b  CIGRE_MV        True
# 1    Bus 1   20.0    b  CIGRE_MV        True
# 2    Bus 2   20.0    b  CIGRE_MV        True
# 3    Bus 3   20.0    b  CIGRE_MV        True
# 4    Bus 4   20.0    b  CIGRE_MV        True
# 5    Bus 5   20.0    b  CIGRE_MV        True
# 6    Bus 6   20.0    b  CIGRE_MV        True
# 7    Bus 7   20.0    b  CIGRE_MV        True
# 8    Bus 8   20.0    b  CIGRE_MV        True
# 9    Bus 9   20.0    b  CIGRE_MV        True
# 10  Bus 10   20.0    b  CIGRE_MV        True
# 11  Bus 11   20.0    b  CIGRE_MV        True
# 12  Bus 12   20.0    b  CIGRE_MV        True
# 13  Bus 13   20.0    b  CIGRE_MV        True
# 14  Bus 14   20.0    b  CIGRE_MV        True
#
#                                                geo  min_vm_pu  max_vm_pu
# 0       {"coordinates":[7.0,16.0], "type":"Point"}       0.95       1.05
# 1    {"coordinates": [4.0, 15.0], "type": "Point"}       0.95       1.05
# 2    {"coordinates": [4.0, 13.0], "type": "Point"}       0.95       1.05
# 3    {"coordinates": [4.0, 11.0], "type": "Point"}       0.95       1.05
# 4     {"coordinates": [2.5, 9.0], "type": "Point"}       0.95       1.05
# 5     {"coordinates": [1.0, 7.0], "type": "Point"}       0.95       1.05
# 6     {"coordinates": [1.0, 3.0], "type": "Point"}       0.95       1.05
# 7     {"coordinates": [8.0, 3.0], "type": "Point"}       0.95       1.05
# 8     {"coordinates": [8.0, 5.0], "type": "Point"}       0.95       1.05
# 9     {"coordinates": [6.0, 5.0], "type": "Point"}       0.95       1.05
# 10    {"coordinates": [4.0, 5.0], "type": "Point"}       0.95       1.05
# 11    {"coordinates": [4.0, 7.0], "type": "Point"}       0.95       1.05
# 12  {"coordinates": [10.0, 15.0], "type": "Point"}       0.95       1.05
# 13  {"coordinates": [10.0, 11.0], "type": "Point"}       0.95       1.05
# 14   {"coordinates": [10.0, 5.0], "type": "Point"}       0.95       1.05

# %%
# Setting load scaling in case needed
for i in range(0, 18):
    net.load.at[i, "scaling"] = 1
net.load
# Out:
#          name  bus      p_mw    q_mvar  const_z_p_percent  const_i_p_percent  \
# 0     Load R1    1  14.99400  3.044662                0.0                0.0
# 1     Load R3    3   0.27645  0.069285                0.0                0.0
# 2     Load R4    4   0.43165  0.108182                0.0                0.0
# 3     Load R5    5   0.72750  0.182329                0.0                0.0
# 4     Load R6    6   0.54805  0.137354                0.0                0.0
# 5     Load R8    8   0.58685  0.147078                0.0                0.0
# 6    Load R10   10   0.47530  0.119121                0.0                0.0
# 7    Load R11   11   0.32980  0.082656                0.0                0.0
# 8    Load R12   12  14.99400  3.044662                0.0                0.0
# 9    Load R14   14   0.20855  0.052268                0.0                0.0
# 10   Load CI1    1   4.84500  1.592474                0.0                0.0
# 11   Load CI3    3   0.22525  0.139597                0.0                0.0
# 12   Load CI7    7   0.07650  0.047410                0.0                0.0
# 13   Load CI9    9   0.57375  0.355578                0.0                0.0
# 14  Load CI10   10   0.06800  0.042143                0.0                0.0
# 15  Load CI12   12   5.01600  1.648679                0.0                0.0
# 16  Load CI13   13   0.03400  0.021071                0.0                0.0
# 17  Load CI14   14   0.33150  0.205445                0.0                0.0
#
#     const_z_q_percent  const_i_q_percent  sn_mva  scaling  in_service type
# 0                 0.0                0.0  15.300      1.0        True  wye
# 1                 0.0                0.0   0.285      1.0        True  wye
# 2                 0.0                0.0   0.445      1.0        True  wye
# 3                 0.0                0.0   0.750      1.0        True  wye
# 4                 0.0                0.0   0.565      1.0        True  wye
# 5                 0.0                0.0   0.605      1.0        True  wye
# 6                 0.0                0.0   0.490      1.0        True  wye
# 7                 0.0                0.0   0.340      1.0        True  wye
# 8                 0.0                0.0  15.300      1.0        True  wye
# 9                 0.0                0.0   0.215      1.0        True  wye
# 10                0.0                0.0   5.100      1.0        True  wye
# 11                0.0                0.0   0.265      1.0        True  wye
# 12                0.0                0.0   0.090      1.0        True  wye
# 13                0.0                0.0   0.675      1.0        True  wye
# 14                0.0                0.0   0.080      1.0        True  wye
# 15                0.0                0.0   5.280      1.0        True  wye
# 16                0.0                0.0   0.040      1.0        True  wye
# 17                0.0                0.0   0.390      1.0        True  wye

# %%
net.line
# Out:
#           name        std_type  from_bus  to_bus  length_km  r_ohm_per_km  \
# 0     Line 1-2  CABLE_CIGRE_MV         1       2       2.82         0.501
# 1     Line 2-3  CABLE_CIGRE_MV         2       3       4.42         0.501
# 2     Line 3-4  CABLE_CIGRE_MV         3       4       0.61         0.501
# 3     Line 4-5  CABLE_CIGRE_MV         4       5       0.56         0.501
# 4     Line 5-6  CABLE_CIGRE_MV         5       6       1.54         0.501
# 5     Line 7-8  CABLE_CIGRE_MV         7       8       1.67         0.501
# 6     Line 8-9  CABLE_CIGRE_MV         8       9       0.32         0.501
# 7    Line 9-10  CABLE_CIGRE_MV         9      10       0.77         0.501
# 8   Line 10-11  CABLE_CIGRE_MV        10      11       0.33         0.501
# 9     Line 3-8  CABLE_CIGRE_MV         3       8       1.30         0.501
# 10  Line 12-13    OHL_CIGRE_MV        12      13       4.89         0.510
# 11  Line 13-14    OHL_CIGRE_MV        13      14       2.99         0.510
# 12    Line 6-7  CABLE_CIGRE_MV         6       7       0.24         0.501
# 13   Line 11-4  CABLE_CIGRE_MV        11       4       0.49         0.501
# 14   Line 14-8    OHL_CIGRE_MV        14       8       2.00         0.510
#
#     x_ohm_per_km  c_nf_per_km  g_us_per_km  max_i_ka   df  parallel type  \
# 0          0.716    151.17490          0.0     0.145  1.0         1   cs
# 1          0.716    151.17490          0.0     0.145  1.0         1   cs
# 2          0.716    151.17490          0.0     0.145  1.0         1   cs
# 3          0.716    151.17490          0.0     0.145  1.0         1   cs
# 4          0.716    151.17490          0.0     0.145  1.0         1   cs
# 5          0.716    151.17490          0.0     0.145  1.0         1   cs
# 6          0.716    151.17490          0.0     0.145  1.0         1   cs
# 7          0.716    151.17490          0.0     0.145  1.0         1   cs
# 8          0.716    151.17490          0.0     0.145  1.0         1   cs
# 9          0.716    151.17490          0.0     0.145  1.0         1   cs
# 10         0.366     10.09679          0.0     0.195  1.0         1   ol
# 11         0.366     10.09679          0.0     0.195  1.0         1   ol
# 12         0.716    151.17490          0.0     0.145  1.0         1   cs
# 13         0.716    151.17490          0.0     0.145  1.0         1   cs
# 14         0.366     10.09679          0.0     0.195  1.0         1   ol
#
#     in_service   geo
# 0         True  None
# 1         True  None
# 2         True  None
# 3         True  None
# 4         True  None
# 5         True  None
# 6         True  None
# 7         True  None
# 8         True  None
# 9         True  None
# 10        True  None
# 11        True  None
# 12        True  None
# 13        True  None
# 14        True  None

# %%
pf_res_plotly(net, auto_open=False, aspectratio=(1.2,1))
# Out:
# There are no Power Flow results. A Newton-Raphson power flow will be executed.

# %%
# Modifiy the reactive power setpoint for all the PV generators
for elem in net.sgen.iterrows():
    if str.startswith(elem[1]["name"], "PV"):  
        p_mw = net.sgen.at[elem[0], "p_mw"]
        net.sgen.at[elem[0], "q_mvar"] = -p_mw * 0.4 # Setting reactive power to -40% of active power (absorbing reactive power)
net.sgen
# TODO: we could study how the number of violated busses changes with the number of compromised PVs
# Out:
#                        name  bus   p_mw  q_mvar  min_q_mvar  max_q_mvar  \
# 0                      PV 3    3  0.120  -0.048     0.00900     0.01500
# 1                      PV 4    4  0.120  -0.048     0.00900     0.01500
# 2                      PV 5    5  0.130  -0.052     0.00975     0.01625
# 3                      PV 6    6  0.130  -0.052     0.00975     0.01625
# 4                      PV 8    8  0.130  -0.052     0.00975     0.01625
# 5                      PV 9    9  0.130  -0.052     0.00975     0.01625
# 6                     PV 10   10  0.140  -0.056     0.01050     0.01750
# 7                     PV 11   11  0.110  -0.044     0.00825     0.01375
# 8                     WKA 7    7  1.500   0.000     0.00000     0.00000
# 9   Residential fuel cell 1    5  0.033   0.000     0.00000     0.00000
# 10             CHP diesel 1    9  0.310   0.000     0.00000     0.00000
# 11              Fuel cell 1    9  0.212   0.000     0.00000     0.00000
# 12  Residential fuel cell 2   10  0.014   0.000     0.00000     0.00000
#
#     sn_mva  scaling  controllable  id_q_capability_characteristic  \
# 0    0.020      1.0          True                            <NA>
# 1    0.020      1.0          True                            <NA>
# 2    0.030      1.0          True                            <NA>
# 3    0.030      1.0          True                            <NA>
# 4    0.030      1.0          True                            <NA>
# 5    0.030      1.0          True                            <NA>
# 6    0.040      1.0          True                            <NA>
# 7    0.010      1.0          True                            <NA>
# 8    1.500      1.0          True                            <NA>
# 9    0.033      1.0         False                            <NA>
# 10   0.310      1.0          True                            <NA>
# 11   0.212      1.0          True                            <NA>
# 12   0.014      1.0         False                            <NA>
#
#     reactive_capability_curve curve_style  in_service                   type  \
# 0                       False         NaN        True                     PV
# 1                       False         NaN        True                     PV
# 2                       False         NaN        True                     PV
# 3                       False         NaN        True                     PV
# 4                       False         NaN        True                     PV
# 5                       False         NaN        True                     PV
# 6                       False         NaN        True                     PV
# 7                       False         NaN        True                     PV
# 8                       False         NaN        True                     WP
# 9                       False         NaN        True  Residential fuel cell
# 10                      False         NaN        True             CHP diesel
# 11                      False         NaN        True              Fuel cell
# 12                      False         NaN        True  Residential fuel cell
#
#     current_source  min_p_mw  max_p_mw
# 0             True     0.120     0.120
# 1             True     0.120     0.120
# 2             True     0.130     0.130
# 3             True     0.130     0.130
# 4             True     0.130     0.130
# 5             True     0.130     0.130
# 6             True     0.140     0.140
# 7             True     0.110     0.110
# 8             True     1.500     1.500
# 9             True     0.033     0.033
# 10            True     0.310     0.310
# 11            True     0.212     0.212
# 12            True     0.014     0.014

# %%
pp.runpp(net)
pf_res_plotly(net, auto_open=False, aspectratio=(1.2,1))
net.res_sgen
# Out:
#      p_mw  q_mvar
# 0   0.120  -0.048
# 1   0.120  -0.048
# 2   0.130  -0.052
# 3   0.130  -0.052
# 4   0.130  -0.052
# 5   0.130  -0.052
# 6   0.140  -0.056
# 7   0.110  -0.044
# 8   1.500   0.000
# 9   0.033   0.000
# 10  0.310   0.000
# 11  0.212   0.000
# 12  0.014   0.000

# %%
pp.runopp(net)
pf_res_plotly(net, auto_open=False, aspectratio=(1.2,1))
# Out:
# no costs are given - overall generated power is minimized

# %%
net.res_sgen
net.res_bus
# Out:
#        vm_pu  va_degree       p_mw     q_mvar     lam_p         lam_q
# 0   1.030000   0.000000 -42.595221 -15.395731  1.000000  7.045086e-20
# 1   0.995274 -35.877028  19.839000   4.637136  1.004470  1.477973e-02
# 2   0.981863 -36.257147   0.000000   0.000000  1.030018  3.730160e-02
# 3   0.960396 -36.852279   0.381700   0.195969  1.071887  7.366325e-02
# 4   0.958490 -36.964804   0.311650   0.095264  1.076380  7.544779e-02
# 5   0.957060 -37.052679   1.164500   0.168297  1.079777  7.666209e-02
# 6   0.955911 -37.112072   0.418050   0.123318  1.082687  7.835027e-02
# 7   0.962134 -36.482356  -1.423500   0.047410  1.065844  8.030870e-02
# 8   0.959152 -36.750803   0.456850   0.133035  1.073095  7.957871e-02
# 9   0.958530 -36.763705  -0.078250   0.341532  1.074215  8.064355e-02
# 10  0.957432 -36.821529   0.589300   0.146097  1.076859  8.201808e-02
# 11  0.957300 -36.828110   0.219800   0.070839  1.077235  8.228021e-02
# 12  1.000146 -35.487100  20.010000   4.693341  1.002684  1.088687e-03
# 13  0.995326 -35.538237   0.034000   0.021071  1.010167  4.658422e-03
# 14  0.992553 -35.567913   0.540050   0.257713  1.014481  6.701502e-03
